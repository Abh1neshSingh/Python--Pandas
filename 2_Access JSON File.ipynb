# %%
import pandas as pd
import numpy as np

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
# access json file

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/57486  2141037947
# 1     https://github.com/pandas-dev/pandas/pull/57482  2140852860
# 2     https://github.com/pandas-dev/pandas/pull/57481  2140717530
# 3     https://github.com/pandas-dev/pandas/pull/57480  2140688996
# 4     https://github.com/pandas-dev/pandas/pull/57479  2140668961
# 5     https://github.com/pandas-dev/pandas/pull/57478  2140653286
# 6     https://github.com/pandas-dev/pandas/pull/57477  2140648682
# 7     https://github.com/pandas-dev/pandas/pull/57476  2140635039
# 8     https://github.com/pandas-dev/pandas/pull/57475  2140629857
# 9     https://github.com/pandas-dev/pandas/pull/57473  2140445686
# 10    https://github.com/pandas-dev/pandas/pull/57471  2140109143
# 11    https://github.com/pandas-dev/pandas/pull/57469  2139979734
# 12  https://github.com/pandas-dev/pandas/issues/57468  2139913602
# 13    https://github.com/pandas-dev/pandas/pull/57467  2139718597
# 14    https://github.com/pandas-dev/pandas/pull/57465  2139644190
# 15  https://github.com/pandas-dev/pandas/issues/57463  2139468884
# 16    https://github.com/pandas-dev/pandas/pull/57462  2139259674
# 17    https://github.com/pandas-dev/pandas/pull/57459  2139012377
# 18    https://github.com/pandas-dev/pandas/pull/57458  2138988285
# 19  https://github.com/pandas-dev/pandas/issues/57457  2138905886
# 20  https://github.com/pandas-dev/pandas/issues/57456  2138783039
# 21  https://github.com/pandas-dev/pandas/issues/57453  2138662863
# 22  https://github.com/pandas-dev/pandas/issues/57452  2138484919
# 23  https://github.com/pandas-dev/pandas/issues/57449  2137739275
# 24  https://github.com/pandas-dev/pandas/issues/57448  2137729540
# 25  https://github.com/pandas-dev/pandas/issues/57447  2137693986
# 26    https://github.com/pandas-dev/pandas/pull/57445  2137626855
# 27    https://github.com/pandas-dev/pandas/pull/57444  2137565223
# 28  https://github.com/pandas-dev/pandas/issues/57443  2137484109
# 29    https://github.com/pandas-dev/pandas/pull/57442  2137415482
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD85nN9mB   57486
# 1   PR_kwDOAA0YD85nNXCb   57482
# 2   PR_kwDOAA0YD85nM6OT   57481
# 3   PR_kwDOAA0YD85nM0mP   57480
# 4   PR_kwDOAA0YD85nMwkG   57479
# 5   PR_kwDOAA0YD85nMtmU   57478
# 6   PR_kwDOAA0YD85nMsta   57477
# 7   PR_kwDOAA0YD85nMqFf   57476
# 8   PR_kwDOAA0YD85nMpGU   57475
# 9   PR_kwDOAA0YD85nL-xu   57473
# 10  PR_kwDOAA0YD85nKxQk   57471
# 11  PR_kwDOAA0YD85nKT7e   57469
# 12   I_kwDOAA0YD85_jH2C   57468
# 13  PR_kwDOAA0YD85nJb-B   57467
# 14  PR_kwDOAA0YD85nJLLx   57465
# 15   I_kwDOAA0YD85_hbRU   57463
# 16  PR_kwDOAA0YD85nH18V   57462
# 17  PR_kwDOAA0YD85nG-RC   57459
# 18  PR_kwDOAA0YD85nG43J   57458
# 19   I_kwDOAA0YD85_fR0e   57457
# 20   I_kwDOAA0YD85_ez0_   57456
# 21   I_kwDOAA0YD85_eWfP   57453
# 22   I_kwDOAA0YD85_drC3   57452
# 23   I_kwDOAA0YD85_a1AL   57449
# 24   I_kwDOAA0YD85_ayoE   57448
# 25   I_kwDOAA0YD85_ap8i   57447
# 26  PR_kwDOAA0YD85nCQfY   57445
# 27  PR_kwDOAA0YD85nCDSH   57444
# 28   I_kwDOAA0YD85_Z2tN   57443
# 29  PR_kwDOAA0YD85nBisC   57442
#
#                                                 title  ... closed_at  \
# 0       CI: Run excel tests on single cpu for windows  ...       NaT
# 1      CLN remove dataframe api consortium entrypoint  ...       NaT
# 2                                  CI: update pyright  ...       NaT
# 3   DEPR: read_csv keywords: keep_date_col, delim_...  ...       NaT
# 4   PERF: Improve performance for fillna with date...  ...       NaT
# 5        PERF: Improve performance for astype is view  ...       NaT
# 6         Remove remaining cow occurrences from tests  ...       NaT
# 7          TYP: simplify read_csv/fwf/table overloads  ...       NaT
# 8   REGR: Index.map adding back tz to tz-agnostic ...  ...       NaT
# 9        DEPR: remove deprecated method `is_anchored`  ...       NaT
# 10  BUG: guess_datetime_format fails to infer time...  ...       NaT
# 11          DEPR: to_pytimedelta return Index[object]  ...       NaT
# 12          Pandas Plot Fails to Open w/ Method Error  ...       NaT
# 13  PERF: RangeIndex.append returns a RangeIndex w...  ...       NaT
# 14  PERF: Return RangeIndex columns in str.extract...  ...       NaT
# 15  DEPR: to_pytimedelta to return Index[object] i...  ...       NaT
# 16  REGR: Behavior differs when adding Series to f...  ...       NaT
# 17  PERF: DataFrame(ndarray) constructor ensure to...  ...       NaT
# 18  PERF: use copy=False in constructor in unstack...  ...       NaT
# 19  BUG: Endianness problem with weird data types ...  ...       NaT
# 20  BUG: Inconsistent date_range output when using...  ...       NaT
# 21  BUG: Inconsistent handling of named column ind...  ...       NaT
# 22  BUG: to_datetime fails to infer timeformat dep...  ...       NaT
# 23  BUG: `read_parquet` times out resolving S3 region  ...       NaT
# 24  BUG(?): Non nano + DatetOffset(component=0) re...  ...       NaT
# 25  BUG: binop methods with `fill_value` not being...  ...       NaT
# 26  PERF: Allow RangeIndex.take to return a RangeI...  ...       NaT
# 27  CLN: Enforce deprecation of using alias for bu...  ...       NaT
# 28                DOC: fix GL08 errors in docstrings   ...       NaT
# 29            adding pow example for dataframe #57419  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER                NaN    0.0
# 1              MEMBER                NaN    1.0
# 2              MEMBER                NaN    0.0
# 3         CONTRIBUTOR                NaN    1.0
# 4              MEMBER                NaN    0.0
# 5              MEMBER                NaN    0.0
# 6              MEMBER                NaN    0.0
# 7              MEMBER                NaN    0.0
# 8              MEMBER                NaN    0.0
# 9         CONTRIBUTOR                NaN    0.0
# 10        CONTRIBUTOR                NaN    0.0
# 11               NONE                NaN    0.0
# 12               NONE                NaN    NaN
# 13             MEMBER                NaN    0.0
# 14             MEMBER                NaN    0.0
# 15             MEMBER                NaN    NaN
# 16             MEMBER                NaN    0.0
# 17             MEMBER                NaN    0.0
# 18             MEMBER                NaN    1.0
# 19               NONE                NaN    NaN
# 20               NONE                NaN    NaN
# 21               NONE                NaN    NaN
# 22               NONE                NaN    NaN
# 23               NONE                NaN    NaN
# 24             MEMBER                NaN    NaN
# 25             MEMBER                NaN    NaN
# 26             MEMBER                NaN    0.0
# 27             MEMBER                NaN    0.0
# 28        CONTRIBUTOR                NaN    NaN
# 29               NONE                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12                                                NaN
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0   I don't want to debug windows builds but we sh...
# 1   Discussed privately\r\n\r\nIn short:\r\n- I'm ...
# 2   Pyright 1.1.348 split `reportGeneralTypeIssues...
# 3   - [X] closes #55569\r\n- [ ] [Tests added and ...
# 4   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 5   - [ ] closes #xxxx (Replace xxxx with the GitH...
# 6                          This should be all of them
# 7                                                None
# 8   - [x] closes #57192 (Replace xxxx with the Git...
# 9   xref #56594\r\n\r\nremoved deprecated methods ...
# 10  - [x] closes #57452(Replace xxxx with the GitH...
# 11  - [x] closes #57463 \r\n- [ ] [Tests added and...
# 12  ### Pandas version checks\n\n- [X] I have chec...
# 13  Discovered in https://github.com/pandas-dev/pa...
# 14  Discovered in https://github.com/pandas-dev/pa...
# 15  https://github.com/pandas-dev/pandas/pull/5245...
# 16  follow up to #56426\r\n\r\nthis was inconsiste...
# 17  Closes https://github.com/pandas-dev/pandas/is...
# 18  xref https://github.com/pandas-dev/pandas/issu...
# 19  ### Pandas version checks\n\n- [X] I have chec...
# 20  ### Pandas version checks\r\n\r\n- [X] I have ...
# 21  ### Pandas version checks\r\n\r\n- [X] I have ...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  ### Pandas version checks\n\n- [X] I have chec...
# 24  ```python\r\nIn [1]: import pandas as pd; from...
# 25  ```python\r\nIn [1]: import pandas as pd; from...
# 26  Discovered in https://github.com/pandas-dev/pa...
# 27  - [ ] closes #xxxx (Replace xxxx with the GitH...
# 28  Pandas has a script for validating docstrings:...
# 29  Added example for DataFrame.pow()\r\n\r\n- [x]...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN         None
# 1                       NaN         None
# 2                       NaN         None
# 3                       NaN         None
# 4                       NaN         None
# 5                       NaN         None
# 6                       NaN         None
# 7                       NaN         None
# 8                       NaN         None
# 9                       NaN         None
# 10                      NaN         None
# 11                      NaN         None
# 12                      NaN         None
# 13                      NaN         None
# 14                      NaN         None
# 15                      NaN         None
# 16                      NaN         None
# 17                      NaN         None
# 18                      NaN         None
# 19                      NaN     reopened
# 20                      NaN         None
# 21                      NaN         None
# 22                      NaN         None
# 23                      NaN         None
# 24                      NaN         None
# 25                      NaN         None
# 26                      NaN         None
# 27                      NaN         None
# 28                      NaN         None
# 29                      NaN         None
#
# [30 rows x 30 columns]

# %%
# othermethod--

# %%
import requests
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
df=data.json()

# %%
df
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57486',
#   'id': 2141037947,
#   'node_id': 'PR_kwDOAA0YD85nN9mB',
#   'number': 57486,
#   'title': 'CI: Run excel tests on single cpu for windows',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-18T15:18:33Z',
#   'updated_at': '2024-02-18T15:18:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57486',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57486',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57486.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57486.patch',
#    'merged_at': None},
#   'body': "I don't want to debug windows builds but we should get ci green again",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57482',
#   'id': 2140852860,
#   'node_id': 'PR_kwDOAA0YD85nNXCb',
#   'number': 57482,
#   'title': 'CLN remove dataframe api consortium entrypoint',
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-18T09:01:11Z',
#   'updated_at': '2024-02-18T09:35:34Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57482',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57482',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57482.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57482.patch',
#    'merged_at': None},
#   'body': "Discussed privately\r\n\r\nIn short:\r\n- I'm no longer involved in the project\r\n- nobody in pandas has much interest in leading the effort\r\n- pandas devs are already carrying out enough (mostly unpaid) maintenance, let's not add to it\r\n\r\nThe Consortium is more than welcome to work on this, but outside of pandas",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57481',
#   'id': 2140717530,
#   'node_id': 'PR_kwDOAA0YD85nM6OT',
#   'number': 57481,
#   'title': 'CI: update pyright',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-18T03:29:59Z',
#   'updated_at': '2024-02-18T03:29:59Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57481',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57481',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57481.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57481.patch',
#    'merged_at': None},
#   'body': 'Pyright 1.1.348 split `reportGeneralTypeIssues` into multiple sub-rules up. Hopefully, this might make it easier to enable some of them more gradually.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57480',
#   'id': 2140688996,
#   'node_id': 'PR_kwDOAA0YD85nM0mP',
#   'number': 57480,
#   'title': 'DEPR: read_csv keywords: keep_date_col, delim_whitespace',
#   'user': {'login': 'rmhowe425',
#    'id': 45905457,
#    'node_id': 'MDQ6VXNlcjQ1OTA1NDU3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45905457?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rmhowe425',
#    'html_url': 'https://github.com/rmhowe425',
#    'followers_url': 'https://api.github.com/users/rmhowe425/followers',
#    'following_url': 'https://api.github.com/users/rmhowe425/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rmhowe425/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rmhowe425/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rmhowe425/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rmhowe425/orgs',
#    'repos_url': 'https://api.github.com/users/rmhowe425/repos',
#    'events_url': 'https://api.github.com/users/rmhowe425/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rmhowe425/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-18T01:34:19Z',
#   'updated_at': '2024-02-18T12:37:43Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57480',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57480',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57480.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57480.patch',
#    'merged_at': None},
#   'body': '- [X] closes #55569\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57479',
#   'id': 2140668961,
#   'node_id': 'PR_kwDOAA0YD85nMwkG',
#   'number': 57479,
#   'title': 'PERF: Improve performance for fillna with datetime',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-18T00:21:26Z',
#   'updated_at': '2024-02-18T12:38:39Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57479',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57479',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57479.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57479.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57478',
#   'id': 2140653286,
#   'node_id': 'PR_kwDOAA0YD85nMtmU',
#   'number': 57478,
#   'title': 'PERF: Improve performance for astype is view',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-17T23:16:27Z',
#   'updated_at': '2024-02-18T12:39:46Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57478',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57478',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57478.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57478.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis came up in asvs, it wasn't much but we can do better",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57477',
#   'id': 2140648682,
#   'node_id': 'PR_kwDOAA0YD85nMsta',
#   'number': 57477,
#   'title': 'Remove remaining cow occurrences from tests',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2085877452,
#     'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics',
#     'name': 'Copy / view semantics',
#     'color': '70e5ca',
#     'default': False,
#     'description': ''}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 49,
#    'closed_issues': 256,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-02-18T13:21:55Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-17T22:58:34Z',
#   'updated_at': '2024-02-18T00:22:36Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57477',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57477',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57477.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57477.patch',
#    'merged_at': None},
#   'body': 'This should be all of them',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57476',
#   'id': 2140635039,
#   'node_id': 'PR_kwDOAA0YD85nMqFf',
#   'number': 57476,
#   'title': 'TYP: simplify read_csv/fwf/table overloads',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-17T22:06:03Z',
#   'updated_at': '2024-02-18T02:09:13Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57476',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57476',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57476.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57476.patch',
#    'merged_at': None},
#   'body': None,
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57475',
#   'id': 2140629857,
#   'node_id': 'PR_kwDOAA0YD85nMpGU',
#   'number': 57475,
#   'title': 'REGR: Index.map adding back tz to tz-agnostic result',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/116',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels',
#    'id': 10403366,
#    'node_id': 'MI_kwDOAA0YD84Anr4m',
#    'number': 116,
#    'title': '2.2.1',
#    'description': 'on-merge: backport to 2.2.x',
#    'creator': {'login': 'lithomas1',
#     'id': 47963215,
#     'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/lithomas1',
#     'html_url': 'https://github.com/lithomas1',
#     'followers_url': 'https://api.github.com/users/lithomas1/followers',
#     'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#     'repos_url': 'https://api.github.com/users/lithomas1/repos',
#     'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 44,
#    'closed_issues': 113,
#    'state': 'open',
#    'created_at': '2024-01-11T01:47:31Z',
#    'updated_at': '2024-02-18T15:15:10Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-17T21:48:03Z',
#   'updated_at': '2024-02-17T21:59:40Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57475',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57475',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57475.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57475.patch',
#    'merged_at': None},
#   'body': "- [x] closes #57192 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nIt seems to me we should skip casting back to the caller's dtype when the caller dtype is datetime, since these are reliably represented as objects (unlike ints, which loses the size). But datetimes/tzs are definitely not in my wheelhouse.\r\n\r\ncc @jbrockmendel ",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57473',
#   'id': 2140445686,
#   'node_id': 'PR_kwDOAA0YD85nL-xu',
#   'number': 57473,
#   'title': 'DEPR: remove deprecated method `is_anchored`',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-17T18:46:12Z',
#   'updated_at': '2024-02-18T07:21:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57473',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57473',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57473.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57473.patch',
#    'merged_at': None},
#   'body': 'xref #56594\r\n\r\nremoved deprecated methods `DateOffset.is_anchored` and `offsets.Tick.is_anchored`',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57471',
#   'id': 2140109143,
#   'node_id': 'PR_kwDOAA0YD85nKxQk',
#   'number': 57471,
#   'title': 'BUG: guess_datetime_format fails to infer timeformat',
#   'user': {'login': 'yuanx749',
#    'id': 47032563,
#    'node_id': 'MDQ6VXNlcjQ3MDMyNTYz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47032563?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yuanx749',
#    'html_url': 'https://github.com/yuanx749',
#    'followers_url': 'https://api.github.com/users/yuanx749/followers',
#    'following_url': 'https://api.github.com/users/yuanx749/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yuanx749/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/yuanx749/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yuanx749/subscriptions',
#    'organizations_url': 'https://api.github.com/users/yuanx749/orgs',
#    'repos_url': 'https://api.github.com/users/yuanx749/repos',
#    'events_url': 'https://api.github.com/users/yuanx749/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/yuanx749/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2024-02-17T13:52:51Z',
#   'updated_at': '2024-02-17T15:57:38Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57471',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57471',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57471.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57471.patch',
#    'merged_at': None},
#   'body': '- [x] closes #57452(Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57469',
#   'id': 2139979734,
#   'node_id': 'PR_kwDOAA0YD85nKT7e',
#   'number': 57469,
#   'title': 'DEPR: to_pytimedelta return Index[object]',
#   'user': {'login': 'lamdang2k',
#    'id': 70220760,
#    'node_id': 'MDQ6VXNlcjcwMjIwNzYw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70220760?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lamdang2k',
#    'html_url': 'https://github.com/lamdang2k',
#    'followers_url': 'https://api.github.com/users/lamdang2k/followers',
#    'following_url': 'https://api.github.com/users/lamdang2k/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lamdang2k/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lamdang2k/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lamdang2k/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lamdang2k/orgs',
#    'repos_url': 'https://api.github.com/users/lamdang2k/repos',
#    'events_url': 'https://api.github.com/users/lamdang2k/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lamdang2k/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2024-02-17T11:22:27Z',
#   'updated_at': '2024-02-17T20:12:09Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57469',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57469',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57469.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57469.patch',
#    'merged_at': None},
#   'body': '- [x] closes #57463 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v3.0.0.rst` file \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57468',
#   'id': 2139913602,
#   'node_id': 'I_kwDOAA0YD85_jH2C',
#   'number': 57468,
#   'title': 'Pandas Plot Fails to Open w/ Method Error',
#   'user': {'login': 'magentoman2009',
#    'id': 3162422,
#    'node_id': 'MDQ6VXNlcjMxNjI0MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3162422?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/magentoman2009',
#    'html_url': 'https://github.com/magentoman2009',
#    'followers_url': 'https://api.github.com/users/magentoman2009/followers',
#    'following_url': 'https://api.github.com/users/magentoman2009/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/magentoman2009/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/magentoman2009/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/magentoman2009/subscriptions',
#    'organizations_url': 'https://api.github.com/users/magentoman2009/orgs',
#    'repos_url': 'https://api.github.com/users/magentoman2009/repos',
#    'events_url': 'https://api.github.com/users/magentoman2009/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/magentoman2009/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 307649777,
#     'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info',
#     'name': 'Needs Info',
#     'color': '207de5',
#     'default': False,
#     'description': 'Clarification about behavior needed to assess issue'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2024-02-17T09:20:44Z',
#   'updated_at': '2024-02-17T18:28:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfrom backtesting import Backtest, Strategy\r\nfrom backtesting.lib import crossover\r\n\r\n# Artificial DataFrame creation\r\ndata = {\r\n    \'datetime\': pd.date_range(start=\'2021-03-11\', periods=7, freq=\'H\'),\r\n    \'open\': [0.3871, 0.336, 0.3416, 0.34, 0.339, 0.4696, 0.4609],\r\n    \'high\': [0.3872, 0.349, 0.3576, 0.3478, 0.59, 0.496, 0.476],\r\n    \'low\': [0.314, 0.3352, 0.34, 0.3376, 0.3386, 0.4056, 0.4074],\r\n    \'close\': [0.3352, 0.3416, 0.34, 0.339, 0.4667, 0.4609, 0.4243],\r\n    \'volume\': [38135576.5, 8590583.9, 11334792.4, 4362490.6, 78260624.4, 52249994.4, 33508243.7]\r\n}\r\ndf = pd.DataFrame(data).set_index(\'datetime\')\r\n\r\n# Minimal Strategy Implementation\r\nclass MinimalStrategy(Strategy):\r\n    def init(self):\r\n        pass\r\n\r\n    def next(self):\r\n        if not self.position:\r\n            self.buy()\r\n\r\n# Backtest Setup\r\nbt = Backtest(df, MinimalStrategy, cash=1_000, commission=.002)\r\n\r\n# Run the backtest\r\noutput = bt.run()\r\nprint(output)\r\n\r\n# Plot the results\r\nbt.plot()\n```\n\n\n### Issue Description\n\nTraceback (most recent call last):\r\n  File "/Users/hidden/Development/Crypto/Bots/BootCamp/Algo/My_Backtesting/sma_backtest_v1.py", line 60, in <module>\r\n    bt.plot()\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/backtesting/backtesting.py", line 1592, in plot\r\n    return plot(\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/backtesting/_plotting.py", line 203, in plot\r\n    df, indicators, equity_data, trades = _maybe_resample_data(\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/backtesting/_plotting.py", line 153, in _maybe_resample_data\r\n    trades = trades.assign(count=1).resample(freq, on=\'ExitTime\', label=\'right\').agg(dict(\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/resample.py", line 352, in aggregate\r\n    result = ResamplerWindowApply(self, func, args=args, kwargs=kwargs).agg()\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/apply.py", line 190, in agg\r\n    return self.agg_dict_like()\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/apply.py", line 423, in agg_dict_like\r\n    return self.agg_or_apply_dict_like(op_name="agg")\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/apply.py", line 1608, in agg_or_apply_dict_like\r\n    result_index, result_data = self.compute_dict_like(\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/apply.py", line 496, in compute_dict_like\r\n    results = [\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/apply.py", line 497, in <listcomp>\r\n    getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 294, in aggregate\r\n    return self._python_agg_general(func, *args, **kwargs)\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 327, in _python_agg_general\r\n    result = self._grouper.agg_series(obj, f)\r\n  File "/Users/hidden/anaconda3/envs/BootCamp_AlgoTrading/lib/python ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
# ...
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 1218227310,
#     'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index',
#     'name': 'Index',
#     'color': 'e99695',
#     'default': False,
#     'description': 'Related to the Index class or subclasses'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 49,
#    'closed_issues': 256,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-02-18T13:21:55Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-15T23:45:09Z',
#   'updated_at': '2024-02-16T21:19:28Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57445',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57445',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57445.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57445.patch',
#    'merged_at': None},
#   'body': 'Discovered in https://github.com/pandas-dev/pandas/pull/57441',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57444',
#   'id': 2137565223,
#   'node_id': 'PR_kwDOAA0YD85nCDSH',
#   'number': 57444,
#   'title': 'CLN: Enforce deprecation of using alias for builtin/NumPy funcs',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 211029535,
#     'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean',
#     'name': 'Clean',
#     'color': '207de5',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/102',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels',
#    'id': 9021906,
#    'node_id': 'MI_kwDOAA0YD84AianS',
#    'number': 102,
#    'title': '3.0',
#    'description': '',
#    'creator': {'login': 'jbrockmendel',
#     'id': 8078968,
#     'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jbrockmendel',
#     'html_url': 'https://github.com/jbrockmendel',
#     'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#     'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#     'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#     'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 49,
#    'closed_issues': 256,
#    'state': 'open',
#    'created_at': '2023-02-08T18:16:49Z',
#    'updated_at': '2024-02-18T13:21:55Z',
#    'due_on': '2024-04-01T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2024-02-15T22:39:46Z',
#   'updated_at': '2024-02-17T22:18:51Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57444',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57444',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57444.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57444.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nRef: #53974',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/57443',
#   'id': 2137484109,
#   'node_id': 'I_kwDOAA0YD85_Z2tN',
#   'number': 57443,
#   'title': 'DOC: fix GL08 errors in docstrings ',
#   'user': {'login': 'jordan-d-murphy',
#    'id': 35613487,
#    'node_id': 'MDQ6VXNlcjM1NjEzNDg3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35613487?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jordan-d-murphy',
#    'html_url': 'https://github.com/jordan-d-murphy',
#    'followers_url': 'https://api.github.com/users/jordan-d-murphy/followers',
#    'following_url': 'https://api.github.com/users/jordan-d-murphy/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jordan-d-murphy/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jordan-d-murphy/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jordan-d-murphy/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jordan-d-murphy/orgs',
#    'repos_url': 'https://api.github.com/users/jordan-d-murphy/repos',
#    'events_url': 'https://api.github.com/users/jordan-d-murphy/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jordan-d-murphy/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 717120670,
#     'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue',
#     'name': 'good first issue',
#     'color': '0e8a16',
#     'default': True,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2024-02-15T21:30:57Z',
#   'updated_at': '2024-02-17T23:10:28Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "Pandas has a script for validating docstrings:\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/92a52e231534de236c4e878008a4365b4b1da291/ci/code_checks.sh#L144-L415\r\n\r\nCurrently, some methods fail the GL08 check.\r\n\r\nThe task here is:\r\n\r\n- take 2-4 methods\r\n- run: scripts/validate_docstrings.py --format=actions --errors=GL08 `method-name`\r\n- check if validation docstrings passes for those methods, and if it’s necessary fix the docstrings according to whatever error is reported\r\n- remove those methods from code_checks.sh\r\n- commit, push, open pull request\r\n\r\nPlease don't comment take as multiple people can work on this issue. You also don't need to ask for permission to work on this, just comment on which methods are you going to work.\r\n\r\nIf you're new contributor, please check the [contributing guide](https://pandas.pydata.org/docs/dev/development/contributing.html)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/57442',
#   'id': 2137415482,
#   'node_id': 'PR_kwDOAA0YD85nBisC',
#   'number': 57442,
#   'title': 'adding pow example for dataframe #57419',
#   'user': {'login': 'santhoshbethi',
#    'id': 45058712,
#    'node_id': 'MDQ6VXNlcjQ1MDU4NzEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45058712?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/santhoshbethi',
#    'html_url': 'https://github.com/santhoshbethi',
#    'followers_url': 'https://api.github.com/users/santhoshbethi/followers',
#    'following_url': 'https://api.github.com/users/santhoshbethi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/santhoshbethi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/santhoshbethi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/santhoshbethi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/santhoshbethi/orgs',
#    'repos_url': 'https://api.github.com/users/santhoshbethi/repos',
#    'events_url': 'https://api.github.com/users/santhoshbethi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/santhoshbethi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 3,
#   'created_at': '2024-02-15T20:42:22Z',
#   'updated_at': '2024-02-18T14:38:04Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57442',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/57442',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/57442.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/57442.patch',
#    'merged_at': None},
#   'body': 'Added example for DataFrame.pow()\r\n\r\n- [x] closes #57419\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
for i in range (len(df)):
    print(df[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57486', 'id': 2141037947, 'node_id': 'PR_kwDOAA0YD85nN9mB', 'number': 57486, 'title': 'CI: Run excel tests on single cpu for windows', 'user': {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-18T15:18:33Z', 'updated_at': '2024-02-18T15:18:33Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57486', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57486', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57486.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57486.patch', 'merged_at': None}, 'body': "I don't want to debug windows builds but we should get ci green again", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57486/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57482', 'id': 2140852860, 'node_id': 'PR_kwDOAA0YD85nNXCb', 'number': 57482, 'title': 'CLN remove dataframe api consortium entrypoint', 'user': {'login': 'MarcoGorelli', 'id': 33491632, 'node_id': 'MDQ6VXNlcjMzNDkxNjMy', 'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarcoGorelli', 'html_url': 'https://github.com/MarcoGorelli', 'followers_url': 'https://api.github.com/users/MarcoGorelli/followers', 'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}', 'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions', 'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs', 'repos_url': 'https://api.github.com/users/MarcoGorelli/repos', 'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-18T09:01:11Z', 'updated_at': '2024-02-18T09:35:34Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': True, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57482', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57482', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57482.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57482.patch', 'merged_at': None}, 'body': "Discussed privately\r\n\r\nIn short:\r\n- I'm no longer involved in the project\r\n- nobody in pandas has much interest in leading the effort\r\n- pandas devs are already carrying out enough (mostly unpaid) maintenance, let's not add to it\r\n\r\nThe Consortium is more than welcome to work on this, but outside of pandas", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57482/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57481', 'id': 2140717530, 'node_id': 'PR_kwDOAA0YD85nM6OT', 'number': 57481, 'title': 'CI: update pyright', 'user': {'login': 'twoertwein', 'id': 6618166, 'node_id': 'MDQ6VXNlcjY2MTgxNjY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/twoertwein', 'html_url': 'https://github.com/twoertwein', 'followers_url': 'https://api.github.com/users/twoertwein/followers', 'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}', 'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions', 'organizations_url': 'https://api.github.com/users/twoertwein/orgs', 'repos_url': 'https://api.github.com/users/twoertwein/repos', 'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}', 'received_events_url': 'https://api.github.com/users/twoertwein/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-18T03:29:59Z', 'updated_at': '2024-02-18T03:29:59Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57481', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57481', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57481.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57481.patch', 'merged_at': None}, 'body': 'Pyright 1.1.348 split `reportGeneralTypeIssues` into multiple sub-rules up. Hopefully, this might make it easier to enable some of them more gradually.', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57481/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57480', 'id': 2140688996, 'node_id': 'PR_kwDOAA0YD85nM0mP', 'number': 57480, 'title': 'DEPR: read_csv keywords: keep_date_col, delim_whitespace', 'user': {'login': 'rmhowe425', 'id': 45905457, 'node_id': 'MDQ6VXNlcjQ1OTA1NDU3', 'avatar_url': 'https://avatars.githubusercontent.com/u/45905457?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rmhowe425', 'html_url': 'https://github.com/rmhowe425', 'followers_url': 'https://api.github.com/users/rmhowe425/followers', 'following_url': 'https://api.github.com/users/rmhowe425/following{/other_user}', 'gists_url': 'https://api.github.com/users/rmhowe425/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rmhowe425/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rmhowe425/subscriptions', 'organizations_url': 'https://api.github.com/users/rmhowe425/orgs', 'repos_url': 'https://api.github.com/users/rmhowe425/repos', 'events_url': 'https://api.github.com/users/rmhowe425/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rmhowe425/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-02-18T01:34:19Z', 'updated_at': '2024-02-18T12:37:43Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': True, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57480', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57480', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57480.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57480.patch', 'merged_at': None}, 'body': '- [X] closes #55569\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [X] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57480/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57479', 'id': 2140668961, 'node_id': 'PR_kwDOAA0YD85nMwkG', 'number': 57479, 'title': 'PERF: Improve performance for fillna with datetime', 'user': {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-18T00:21:26Z', 'updated_at': '2024-02-18T12:38:39Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57479', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57479', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57479.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57479.patch', 'merged_at': None}, 'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57479/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57478', 'id': 2140653286, 'node_id': 'PR_kwDOAA0YD85nMtmU', 'number': 57478, 'title': 'PERF: Improve performance for astype is view', 'user': {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-17T23:16:27Z', 'updated_at': '2024-02-18T12:39:46Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57478', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57478', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57478.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57478.patch', 'merged_at': None}, 'body': "- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis came up in asvs, it wasn't much but we can do better", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57478/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57477', 'id': 2140648682, 'node_id': 'PR_kwDOAA0YD85nMsta', 'number': 57477, 'title': 'Remove remaining cow occurrences from tests', 'user': {'login': 'phofl', 'id': 61934744, 'node_id': 'MDQ6VXNlcjYxOTM0NzQ0', 'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/phofl', 'html_url': 'https://github.com/phofl', 'followers_url': 'https://api.github.com/users/phofl/followers', 'following_url': 'https://api.github.com/users/phofl/following{/other_user}', 'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions', 'organizations_url': 'https://api.github.com/users/phofl/orgs', 'repos_url': 'https://api.github.com/users/phofl/repos', 'events_url': 'https://api.github.com/users/phofl/events{/privacy}', 'received_events_url': 'https://api.github.com/users/phofl/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 2085877452, 'node_id': 'MDU6TGFiZWwyMDg1ODc3NDUy', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Copy%20/%20view%20semantics', 'name': 'Copy / view semantics', 'color': '70e5ca', 'default': False, 'description': ''}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 49, 'closed_issues': 256, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-02-18T13:21:55Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-02-17T22:58:34Z', 'updated_at': '2024-02-18T00:22:36Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57477', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57477', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57477.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57477.patch', 'merged_at': None}, 'body': 'This should be all of them', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57477/reactions', 'total_count': 0, '+1' ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57476', 'id': 2140635039, 'node_id': 'PR_kwDOAA0YD85nMqFf', 'number': 57476, 'title': 'TYP: simplify read_csv/fwf/table overloads', 'user': {'login': 'twoertwein', 'id': 6618166, 'node_id': 'MDQ6VXNlcjY2MTgxNjY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/twoertwein', 'html_url': 'https://github.com/twoertwein', 'followers_url': 'https://api.github.com/users/twoertwein/followers', 'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}', 'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions', 'organizations_url': 'https://api.github.com/users/twoertwein/orgs', 'repos_url': 'https://api.github.com/users/twoertwein/repos', 'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}', 'received_events_url': 'https://api.github.com/users/twoertwein/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-17T22:06:03Z', 'updated_at': '2024-02-18T02:09:13Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57476', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57476', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57476.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57476.patch', 'merged_at': None}, 'body': None, 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57476/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57475/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57475', 'id': 2140629857, 'node_id': 'PR_kwDOAA0YD85nMpGU', 'number': 57475, 'title': 'REGR: Index.map adding back tz to tz-agnostic result', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression', 'name': 'Regression', 'color': 'e11d21', 'default': False, 'description': 'Functionality that used to work in a prior pandas version'}, {'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply', 'name': 'Apply', 'color': 'fbca04', 'default': False, 'description': 'Apply, Aggregate, Transform'}, {'id': 1218227310, 'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index', 'name': 'Index', 'color': 'e99695', 'default': False, 'description': 'Related to the Index class or subclasses'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/116', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/116/labels', 'id': 10403366, 'node_id': 'MI_kwDOAA0YD84Anr4m', 'number': 116, 'title': '2.2.1', 'description': 'on-merge: backport to 2.2.x', 'creator': {'login': 'lithomas1', 'id': 47963215, 'node_id': 'MDQ6VXNlcjQ3OTYzMjE1', 'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lithomas1', 'html_url': 'https://github.com/lithomas1', 'followers_url': 'https://api.github.com/users/lithomas1/followers', 'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}', 'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions', 'organizations_url': 'https://api.github.com/users/lithomas1/orgs', 'repos_url': 'https://api.github.com/users/lithomas1/repos', 'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lithomas1/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 44, 'closed_issues': 113, 'state': 'open', 'created_at': '2024-01-11T01:47:31Z', 'updated_at': '2024-02-18T15:15:10Z', 'due_on': None, 'closed_at': None}, 'comments': 0, 'created_at': '2024-02-17T21:48:03Z', 'updated_at': '2024-02-17T21:59:40Z', 'closed_at': ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57473', 'id': 2140445686, 'node_id': 'PR_kwDOAA0YD85nL-xu', 'number': 57473, 'title': 'DEPR: remove deprecated method `is_anchored`', 'user': {'login': 'natmokval', 'id': 91160475, 'node_id': 'MDQ6VXNlcjkxMTYwNDc1', 'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/natmokval', 'html_url': 'https://github.com/natmokval', 'followers_url': 'https://api.github.com/users/natmokval/followers', 'following_url': 'https://api.github.com/users/natmokval/following{/other_user}', 'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions', 'organizations_url': 'https://api.github.com/users/natmokval/orgs', 'repos_url': 'https://api.github.com/users/natmokval/repos', 'events_url': 'https://api.github.com/users/natmokval/events{/privacy}', 'received_events_url': 'https://api.github.com/users/natmokval/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 87485152, 'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate', 'name': 'Deprecate', 'color': '5319e7', 'default': False, 'description': 'Functionality to remove in pandas'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-17T18:46:12Z', 'updated_at': '2024-02-18T07:21:17Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57473', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57473', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57473.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57473.patch', 'merged_at': None}, 'body': 'xref #56594\r\n\r\nremoved deprecated methods `DateOffset.is_anchored` and `offsets.Tick.is_anchored`', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57473/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57471', 'id': 2140109143, 'node_id': 'PR_kwDOAA0YD85nKxQk', 'number': 57471, 'title': 'BUG: guess_datetime_format fails to infer timeformat', 'user': {'login': 'yuanx749', 'id': 47032563, 'node_id': 'MDQ6VXNlcjQ3MDMyNTYz', 'avatar_url': 'https://avatars.githubusercontent.com/u/47032563?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/yuanx749', 'html_url': 'https://github.com/yuanx749', 'followers_url': 'https://api.github.com/users/yuanx749/followers', 'following_url': 'https://api.github.com/users/yuanx749/following{/other_user}', 'gists_url': 'https://api.github.com/users/yuanx749/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/yuanx749/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/yuanx749/subscriptions', 'organizations_url': 'https://api.github.com/users/yuanx749/orgs', 'repos_url': 'https://api.github.com/users/yuanx749/repos', 'events_url': 'https://api.github.com/users/yuanx749/events{/privacy}', 'received_events_url': 'https://api.github.com/users/yuanx749/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 1, 'created_at': '2024-02-17T13:52:51Z', 'updated_at': '2024-02-17T15:57:38Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57471', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57471', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57471.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57471.patch', 'merged_at': None}, 'body': '- [x] closes #57452(Replace xxxx with the GitHub issue number)\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57471/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57469', 'id': 2139979734, 'node_id': 'PR_kwDOAA0YD85nKT7e', 'number': 57469, 'title': 'DEPR: to_pytimedelta return Index[object]', 'user': {'login': 'lamdang2k', 'id': 70220760, 'node_id': 'MDQ6VXNlcjcwMjIwNzYw', 'avatar_url': 'https://avatars.githubusercontent.com/u/70220760?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lamdang2k', 'html_url': 'https://github.com/lamdang2k', 'followers_url': 'https://api.github.com/users/lamdang2k/followers', 'following_url': 'https://api.github.com/users/lamdang2k/following{/other_user}', 'gists_url': 'https://api.github.com/users/lamdang2k/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lamdang2k/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lamdang2k/subscriptions', 'organizations_url': 'https://api.github.com/users/lamdang2k/orgs', 'repos_url': 'https://api.github.com/users/lamdang2k/repos', 'events_url': 'https://api.github.com/users/lamdang2k/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lamdang2k/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-17T11:22:27Z', 'updated_at': '2024-02-17T20:12:09Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57469', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57469', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57469.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57469.patch', 'merged_at': None}, 'body': '- [x] closes #57463 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added an entry in the latest `doc/source/whatsnew/v3.0.0.rst` file \r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57469/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57468/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57468', 'id': 2139913602, 'node_id': 'I_kwDOAA0YD85_jH2C', 'number': 57468, 'title': 'Pandas Plot Fails to Open w/ Method Error', 'user': {'login': 'magentoman2009', 'id': 3162422, 'node_id': 'MDQ6VXNlcjMxNjI0MjI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3162422?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/magentoman2009', 'html_url': 'https://github.com/magentoman2009', 'followers_url': 'https://api.github.com/users/magentoman2009/followers', 'following_url': 'https://api.github.com/users/magentoman2009/following{/other_user}', 'gists_url': 'https://api.github.com/users/magentoman2009/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/magentoman2009/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/magentoman2009/subscriptions', 'organizations_url': 'https://api.github.com/users/magentoman2009/orgs', 'repos_url': 'https://api.github.com/users/magentoman2009/repos', 'events_url': 'https://api.github.com/users/magentoman2009/events{/privacy}', 'received_events_url': 'https://api.github.com/users/magentoman2009/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug', 'name': 'Bug', 'color': 'e10c02', 'default': False, 'description': None}, {'id': 307649777, 'node_id': 'MDU6TGFiZWwzMDc2NDk3Nzc=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info', 'name': 'Needs Info', 'color': '207de5', 'default': False, 'description': 'Clarification about behavior needed to assess issue'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 4, 'created_at': '2024-02-17T09:20:44Z', 'updated_at': '2024-02-17T18:28:48Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nfrom backtesting import Backtest, Strategy\r\nfrom backtesting.lib import crossover\r\n\r\n# Artificial DataFrame creation\r\ndata = {\r\n    \'datetime\': pd.date_range(start=\'2021-03-11\', periods=7, freq=\'H\'),\r\n    \'open\': [0.3871, 0.336, 0.3416, 0.34, 0.339, 0.4696, 0.4609],\r\n    \'high\': [0.3872, 0.349, 0.3576, 0.3478, 0.59, 0.496, 0.476],\r\n    \'low\': [0.314, 0.3352, 0.34, 0.3376, 0.3386, 0.4056, 0.4074],\r\n    \'close\': [0.3352, 0.3416, 0.34, 0.339, 0.4667, 0.4609, 0.4243],\r\n    \'volume\': [38135576.5, 8590583.9, 11334792.4, 4362490.6, 78260624.4, 52249994.4, 33508243.7]\r\n}\r\ndf = pd.DataFrame(data).set_index(\'datetime\')\r\n\r\n# Minimal Strategy Implementation\r\nclass MinimalStrategy(Strategy):\r\n    def init(self):\r\n        pass\r\n\r\n    def next(self):\r\n        if not self.position:\r\n            self.buy()\r\n\r\n# Backtest Setup\r\nbt = Backtest(df, MinimalStrategy, cash=1_000, commission=.002)\r\n\r\n# Run the backtest\r\noutput = bt.run()\r\nprint(output)\r\n\r\n# Plot the results\r\nbt.plot()\n```\n\n\n### Issue Description\n\nTraceback (most recent call last):\r\n  File "/Users/hidden/Development/Crypto/Bots/BootCa ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57467', 'id': 2139718597, 'node_id': 'PR_kwDOAA0YD85nJb-B', 'number': 57467, 'title': 'PERF: RangeIndex.append returns a RangeIndex when possible', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 1218227310, 'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index', 'name': 'Index', 'color': 'e99695', 'default': False, 'description': 'Related to the Index class or subclasses'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-17T01:16:24Z', 'updated_at': '2024-02-17T01:17:41Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57467', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57467', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57467.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57467.patch', 'merged_at': None}, 'body': 'Discovered in https://github.com/pandas-dev/pandas/pull/57441', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57467/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57465', 'id': 2139644190, 'node_id': 'PR_kwDOAA0YD85nJLLx', 'number': 57465, 'title': 'PERF: Return RangeIndex columns in str.extract when possible', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1MzEx', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance', 'name': 'Performance', 'color': 'a10c02', 'default': False, 'description': 'Memory or execution speed performance'}, {'id': 57522093, 'node_id': 'MDU6TGFiZWw1NzUyMjA5Mw==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Strings', 'name': 'Strings', 'color': '5319e7', 'default': False, 'description': 'String extension data type and string data'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 0, 'created_at': '2024-02-16T23:50:06Z', 'updated_at': '2024-02-16T23:50:06Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57465', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57465', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57465.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57465.patch', 'merged_at': None}, 'body': 'Discovered in https://github.com/pandas-dev/pandas/pull/57441', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57465/timeline', 'performed_via_github_app': None, 'state_reason': None}
# ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57445/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57445', 'id': 2137626855, 'node_id': 'PR_kwDOAA0YD85nCQfY', 'number': 57445, 'title': 'PERF: Allow RangeIndex.take to return a RangeIndex when possible', 'user': {'login': 'mroeschke', 'id': 10647082, 'node_id': 'MDQ6VXNlcjEwNjQ3MDgy', 'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/mroeschke', 'html_url': 'https://github.com/mroeschke', 'followers_url': 'https://api.github.com/users/mroeschke/followers', 'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}', 'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions', 'organizations_url': 'https://api.github.com/users/mroeschke/orgs', 'repos_url': 'https://api.github.com/users/mroeschke/repos', 'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}', 'received_events_url': 'https://api.github.com/users/mroeschke/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1MzEx', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance', 'name': 'Performance', 'color': 'a10c02', 'default': False, 'description': 'Memory or execution speed performance'}, {'id': 1218227310, 'node_id': 'MDU6TGFiZWwxMjE4MjI3MzEw', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Index', 'name': 'Index', 'color': 'e99695', 'default': False, 'description': 'Related to the Index class or subclasses'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 49, 'closed_issues': 256, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-02-18T13:21:55Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-02-15T23:45:09Z', 'updated_at': '2024-02-16T21:19:28Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57445', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57445 ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57444/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57444', 'id': 2137565223, 'node_id': 'PR_kwDOAA0YD85nCDSH', 'number': 57444, 'title': 'CLN: Enforce deprecation of using alias for builtin/NumPy funcs', 'user': {'login': 'rhshadrach', 'id': 45562402, 'node_id': 'MDQ6VXNlcjQ1NTYyNDAy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/rhshadrach', 'html_url': 'https://github.com/rhshadrach', 'followers_url': 'https://api.github.com/users/rhshadrach/followers', 'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}', 'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions', 'organizations_url': 'https://api.github.com/users/rhshadrach/orgs', 'repos_url': 'https://api.github.com/users/rhshadrach/repos', 'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}', 'received_events_url': 'https://api.github.com/users/rhshadrach/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 211029535, 'node_id': 'MDU6TGFiZWwyMTEwMjk1MzU=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean', 'name': 'Clean', 'color': '207de5', 'default': False, 'description': None}, {'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply', 'name': 'Apply', 'color': 'fbca04', 'default': False, 'description': 'Apply, Aggregate, Transform'}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102', 'html_url': 'https://github.com/pandas-dev/pandas/milestone/102', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/102/labels', 'id': 9021906, 'node_id': 'MI_kwDOAA0YD84AianS', 'number': 102, 'title': '3.0', 'description': '', 'creator': {'login': 'jbrockmendel', 'id': 8078968, 'node_id': 'MDQ6VXNlcjgwNzg5Njg=', 'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jbrockmendel', 'html_url': 'https://github.com/jbrockmendel', 'followers_url': 'https://api.github.com/users/jbrockmendel/followers', 'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}', 'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions', 'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs', 'repos_url': 'https://api.github.com/users/jbrockmendel/repos', 'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events', 'type': 'User', 'site_admin': False}, 'open_issues': 49, 'closed_issues': 256, 'state': 'open', 'created_at': '2023-02-08T18:16:49Z', 'updated_at': '2024-02-18T13:21:55Z', 'due_on': '2024-04-01T07:00:00Z', 'closed_at': None}, 'comments': 0, 'created_at': '2024-02-15T22:39:46Z', 'updated_at': '2024-02-17T22:18:51Z', 'closed_at': None, 'author_association': 'MEMBER', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57444', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57444', 'diff_url': 'https://github.com/pandas-de ...
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/events', 'html_url': 'https://github.com/pandas-dev/pandas/issues/57443', 'id': 2137484109, 'node_id': 'I_kwDOAA0YD85_Z2tN', 'number': 57443, 'title': 'DOC: fix GL08 errors in docstrings ', 'user': {'login': 'jordan-d-murphy', 'id': 35613487, 'node_id': 'MDQ6VXNlcjM1NjEzNDg3', 'avatar_url': 'https://avatars.githubusercontent.com/u/35613487?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jordan-d-murphy', 'html_url': 'https://github.com/jordan-d-murphy', 'followers_url': 'https://api.github.com/users/jordan-d-murphy/followers', 'following_url': 'https://api.github.com/users/jordan-d-murphy/following{/other_user}', 'gists_url': 'https://api.github.com/users/jordan-d-murphy/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jordan-d-murphy/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jordan-d-murphy/subscriptions', 'organizations_url': 'https://api.github.com/users/jordan-d-murphy/orgs', 'repos_url': 'https://api.github.com/users/jordan-d-murphy/repos', 'events_url': 'https://api.github.com/users/jordan-d-murphy/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jordan-d-murphy/received_events', 'type': 'User', 'site_admin': False}, 'labels': [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OTk=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs', 'name': 'Docs', 'color': '3465A4', 'default': False, 'description': None}, {'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI', 'name': 'CI', 'color': 'a2bca7', 'default': False, 'description': 'Continuous Integration'}, {'id': 717120670, 'node_id': 'MDU6TGFiZWw3MTcxMjA2NzA=', 'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/good%20first%20issue', 'name': 'good first issue', 'color': '0e8a16', 'default': True, 'description': None}], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 2, 'created_at': '2024-02-15T21:30:57Z', 'updated_at': '2024-02-17T23:10:28Z', 'closed_at': None, 'author_association': 'CONTRIBUTOR', 'active_lock_reason': None, 'body': "Pandas has a script for validating docstrings:\r\n\r\nhttps://github.com/pandas-dev/pandas/blob/92a52e231534de236c4e878008a4365b4b1da291/ci/code_checks.sh#L144-L415\r\n\r\nCurrently, some methods fail the GL08 check.\r\n\r\nThe task here is:\r\n\r\n- take 2-4 methods\r\n- run: scripts/validate_docstrings.py --format=actions --errors=GL08 `method-name`\r\n- check if validation docstrings passes for those methods, and if it’s necessary fix the docstrings according to whatever error is reported\r\n- remove those methods from code_checks.sh\r\n- commit, push, open pull request\r\n\r\nPlease don't comment take as multiple people can work on this issue. You also don't need to ask for permission to work on this, just comment on which methods are you going to work.\r\n\r\nIf you're new contributor, please check the [contributing guide](https://pandas.pydata.org/docs/dev/development/contributing.html)", 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57443/timeline', 'performed_via_github_app': None, 'state_reason': None}
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57442', 'id': 2137415482, 'node_id': 'PR_kwDOAA0YD85nBisC', 'number': 57442, 'title': 'adding pow example for dataframe #57419', 'user': {'login': 'santhoshbethi', 'id': 45058712, 'node_id': 'MDQ6VXNlcjQ1MDU4NzEy', 'avatar_url': 'https://avatars.githubusercontent.com/u/45058712?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/santhoshbethi', 'html_url': 'https://github.com/santhoshbethi', 'followers_url': 'https://api.github.com/users/santhoshbethi/followers', 'following_url': 'https://api.github.com/users/santhoshbethi/following{/other_user}', 'gists_url': 'https://api.github.com/users/santhoshbethi/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/santhoshbethi/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/santhoshbethi/subscriptions', 'organizations_url': 'https://api.github.com/users/santhoshbethi/orgs', 'repos_url': 'https://api.github.com/users/santhoshbethi/repos', 'events_url': 'https://api.github.com/users/santhoshbethi/events{/privacy}', 'received_events_url': 'https://api.github.com/users/santhoshbethi/received_events', 'type': 'User', 'site_admin': False}, 'labels': [], 'state': 'open', 'locked': False, 'assignee': None, 'assignees': [], 'milestone': None, 'comments': 3, 'created_at': '2024-02-15T20:42:22Z', 'updated_at': '2024-02-18T14:38:04Z', 'closed_at': None, 'author_association': 'NONE', 'active_lock_reason': None, 'draft': False, 'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/57442', 'html_url': 'https://github.com/pandas-dev/pandas/pull/57442', 'diff_url': 'https://github.com/pandas-dev/pandas/pull/57442.diff', 'patch_url': 'https://github.com/pandas-dev/pandas/pull/57442.patch', 'merged_at': None}, 'body': 'Added example for DataFrame.pow()\r\n\r\n- [x] closes #57419\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n', 'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/reactions', 'total_count': 0, '+1': 0, '-1': 0, 'laugh': 0, 'hooray': 0, 'confused': 0, 'heart': 0, 'rocket': 0, 'eyes': 0}, 'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/57442/timeline', 'performed_via_github_app': None, 'state_reason': None}

# %%
for i in range(len(df)):
    print(df[i]['user']['node_id'])
# Out:
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjMzNDkxNjMy
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjQ1OTA1NDU3
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjkxMTYwNDc1
# MDQ6VXNlcjQ3MDMyNTYz
# MDQ6VXNlcjcwMjIwNzYw
# MDQ6VXNlcjMxNjI0MjI=
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjEwMjA0OTY=
# MDQ6VXNlcjQzOTk5NjQx
# MDQ6VXNlcjI2NTc0MjEx
# MDQ6VXNlcjExNDA2MDAy
# U_kgDOCI-v2Q
# MDQ6VXNlcjUzOTU2ODYz
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjQ1NTYyNDAy
# MDQ6VXNlcjM1NjEzNDg3
# MDQ6VXNlcjQ1MDU4NzEy

# %%
df1=pd.DataFrame(df,columns=['user','timeline_url'])

# %%
df1.to_csv('test3.csv')
